# %%
import numpy as np 


arr = np.loadtxt("TestData.txt")

arr
# Out:
# array([[342943, 153607,      4],
#        [342944, 153607,      4],
#        [342945, 153607,      4],
#        [342945, 153608,      4],
#        [342946, 153607,      4],
#        [342946, 153608,      4],
#        [342947, 153607,      4],
#        [342947, 153608,      4],
#        [342947, 153609,      4],
#        [342948, 153607,      4],
#        [342948, 153608,      4],
#        [342948, 153609,      4],
#        [342949, 153607,      4],
#        [342949, 153608,      4],
#        [342949, 153609,      4],
#        [342949, 153610,      4],
#        [342950, 153607,      4],
#        [342950, 153608,      4],
#        [342950, 153609,      4],
#        [342950, 153610,      4],
#        [342950, 153611,      4],
#        [342951, 153607,      4],
#        [342951, 153608,      4],
#        [342951, 153609,      4],
#        [342951, 153610,      4],
#        [342951, 153611,      4],
#        [342952, 153607,      4],
#        [342952, 153608,      4],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(arr[:,0],arr[:,1])
plt.show()
